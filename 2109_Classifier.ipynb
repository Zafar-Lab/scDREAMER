# %% [markdown]
# <a href="https://colab.research.google.com/github/Zafar-Lab/scDREAMER/blob/main/2109_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# Out:
# WARNING: Tensorflow 1 is deprecated, and support will be removed on August 1, 2022.
# After that, `%tensorflow_version 1.x` will throw an error.
#
# Your notebook should be updated to use Tensorflow 2.
# See the guide at https://www.tensorflow.org/guide/migrate#migrate-from-tensorflow-1x-to-tensorflow-2.
#
# TensorFlow 1.x selected.

# %%
import tensorflow as tf

# %%
import warnings
warnings.filterwarnings('ignore')
# !pip install -U scipy==1.5.0
# !pip install scanpy==1.8.2
# !pip install -U scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scipy==1.5.0 in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from scipy==1.5.0) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scanpy==1.8.2 in /usr/local/lib/python3.7/dist-packages (1.8.2)
# Requirement already satisfied: matplotlib>=3.1.2 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (3.5.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (21.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (3.7.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (0.5.2)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (1.5.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (4.64.0)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (2.6.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (1.0.2)
# Requirement already satisfied: umap-learn>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (0.5.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (0.11.2)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (3.1.0)
# Requirement already satisfied: pandas>=0.21 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (1.3.5)
# Requirement already satisfied: sinfo in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (0.3.4)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (0.10.2)
# Requirement already satisfied: importlib_metadata>=0.7 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (4.12.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (5.5.0)
# Requirement already satisfied: anndata>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (0.8.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (1.1.0)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.7/dist-packages (from scanpy==1.8.2) (0.51.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.7/dist-packages (from anndata>=0.7.4->scanpy==1.8.2) (4.1.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.10.0->scanpy==1.8.2) (1.5.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib_metadata>=0.7->scanpy==1.8.2) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.1.2->scanpy==1.8.2) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.1.2->scanpy==1.8.2) (4.34.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.1.2->scanpy==1.8.2) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.1.2->scanpy==1.8.2) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.1.2->scanpy==1.8.2) (1.4.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.1.2->scanpy==1.8.2) (0.11.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.41.0->scanpy==1.8.2) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.41.0->scanpy==1.8.2) (57.4.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->scanpy==1.8.2) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->scanpy==1.8.2) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->scanpy==1.8.2) (3.1.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.3.10->scanpy==1.8.2) (0.5.7)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.7/dist-packages (from sinfo->scanpy==1.8.2) (0.8.0)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->scanpy==1.8.2) (2.8.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.1.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np

# %%
tf.enable_eager_execution()
np.random.seed(0)
tf.set_random_seed(0)

# %% [markdown]
# Building model

# %%
import model

run_config = tf.ConfigProto()
run_config.gpu_options.per_process_gpu_memory_fraction = 0.333
run_config.gpu_options.allow_growth = True

with tf.Session(config = run_config) as sess:

    dreamer = model.scDREAMER(
        sess,
        epoch = 250,
        dataset_name = '/content/drive/MyDrive/IIT Kanpur/scRNA_Data/All_h5ad/Pancreas.h5ad'
        )

    dreamer.train_cluster()
# Out:
# came in load_gene
# updated hvg
# here [8 8 8 ... 8 8 8]
# Shape self.data_train: (16382, 2000)
# Shape self.data_test: (16382, 2000)
# WARNING:tensorflow:From /content/model.py:9: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# encoder input shape  Tensor("concat:0", shape=(?, 2009), dtype=float32)
# WARNING:tensorflow:From /content/model.py:279: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/utils.py:18: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/model.py:308: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/model.py:42: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/model.py:586: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# decoder input shape  Tensor("concat_2:0", shape=(?, 19), dtype=float32)
# WARNING:tensorflow:From /content/utils.py:41: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/utils.py:41: The name tf.lgamma is deprecated. Please use tf.math.lgamma instead.
#
# KL gaussian z Tensor("mul_10:0", shape=(?,), dtype=float32)
# KL gaussian l Tensor("mul_9:0", shape=(?,), dtype=float32)
# WARNING:tensorflow:From /content/model.py:105: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/model.py:122: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /content/model.py:133: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Cluster DRA on DataSet /content/drive/MyDrive/IIT Kanpur/scRNA_Data/All_h5ad/Pancreas.h5ad ...
# WARNING:tensorflow:From /content/model.py:144: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/model.py:165: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Epoch : [0] ,  a_loss = 680.6221, d_loss: inf ,  g_loss: inf,  db_loss: 2.8672
# Epoch : [1] ,  a_loss = 468.0207, d_loss: inf ,  g_loss: inf,  db_loss: 1.3807
# Epoch : [2] ,  a_loss = 705.5315, d_loss: inf ,  g_loss: inf,  db_loss: 2.5042
# Epoch : [3] ,  a_loss = 630.7659, d_loss: inf ,  g_loss: inf,  db_loss: 2.2513
# Epoch : [4] ,  a_loss = 602.0043, d_loss: inf ,  g_loss: inf,  db_loss: 1.6609
# Epoch : [5] ,  a_loss = 451.6804, d_loss: inf ,  g_loss: inf,  db_loss: 2.1524
# Epoch : [6] ,  a_loss = 388.1318, d_loss: inf ,  g_loss: inf,  db_loss: 0.8576
# Epoch : [7] ,  a_loss = 657.6108, d_loss: inf ,  g_loss: inf,  db_loss: 1.1946
# Epoch : [8] ,  a_loss = 365.1278, d_loss: inf ,  g_loss: inf,  db_loss: 0.9882
# Epoch : [9] ,  a_loss = 591.5801, d_loss: inf ,  g_loss: inf,  db_loss: 1.8997
# Epoch : [10] ,  a_loss = 647.0645, d_loss: inf ,  g_loss: inf,  db_loss: 1.4740
# Epoch : [11] ,  a_loss = 607.4882, d_loss: inf ,  g_loss: inf,  db_loss: 2.3453
# Epoch : [12] ,  a_loss = 487.8304, d_loss: inf ,  g_loss: inf,  db_loss: 1.8879
# Epoch : [13] ,  a_loss = 593.3069, d_loss: inf ,  g_loss: inf,  db_loss: 2.3437
# Epoch : [14] ,  a_loss = 419.6209, d_loss: inf ,  g_loss: inf,  db_loss: 0.7931
# Epoch : [15] ,  a_loss = 553.6172, d_loss: inf ,  g_loss: inf,  db_loss: 1.5549
# Epoch : [16] ,  a_loss = 405.7151, d_loss: inf ,  g_loss: inf,  db_loss: 1.9316
# Epoch : [17] ,  a_loss = 647.3188, d_loss: inf ,  g_loss: inf,  db_loss: 2.5872
# Epoch : [18] ,  a_loss = 385.8535, d_loss: inf ,  g_loss: inf,  db_loss: 1.8725
# Epoch : [19] ,  a_loss = 594.4584, d_loss: inf ,  g_loss: inf,  db_loss: 0.9301
# Epoch : [20] ,  a_loss = 495.2243, d_loss: inf ,  g_loss: inf,  db_loss: 1.2753
# Epoch : [21] ,  a_loss = 447.5683, d_loss: inf ,  g_loss: inf,  db_loss: 1.8143
# Epoch : [22] ,  a_loss = 609.6800, d_loss: inf ,  g_loss: inf,  db_loss: 1.2742
# Epoch : [23] ,  a_loss = 611.2510, d_loss: inf ,  g_loss: inf,  db_loss: 2.2943
# Epoch : [24] ,  a_loss = 596.2625, d_loss: inf ,  g_loss: inf,  db_loss: 2.6518
# Epoch : [25] ,  a_loss = 628.6238, d_loss: inf ,  g_loss: inf,  db_loss: 2.0343
# Epoch : [26] ,  a_loss = 616.2870, d_loss: inf ,  g_loss: inf,  db_loss: 1.5583
# Epoch : [27] ,  a_loss = 642.2542, d_loss: inf ,  g_loss: inf,  db_loss: 1.4194
# Epoch : [28] ,  a_loss = 401.7731, d_loss: inf ,  g_loss: inf,  db_loss: 1.4861
# Epoch : [29] ,  a_loss = 415.3879, d_loss: inf ,  g_loss: inf,  db_loss: 2.1423
# Epoch : [30] ,  a_loss = 430.7711, d_loss: inf ,  g_loss: inf,  db_loss: 2.3250
# Epoch : [31] ,  a_loss = 380.5600, d_loss: inf ,  g_loss: inf,  db_loss: 1.0892
# Epoch : [32] ,  a_loss = 380.6139, d_loss: inf ,  g_loss: inf,  db_loss: 0.8208
# Epoch : [33] ,  a_loss = 373.9525, d_loss: inf ,  g_loss: inf,  db_loss: 2.7004
# Epoch : [34] ,  a_loss = 652.3021, d_loss: inf ,  g_loss: inf,  db_loss: 1.6678
# Epoch : [35] ,  a_loss = 644.4357, d_loss: inf ,  g_loss: inf,  db_loss: 1.7911
# Epoch : [36] ,  a_loss = 445.3516, d_loss: inf ,  g_loss: inf,  db_loss: 2.3171
# Epoch : [37] ,  a_loss = 570.2325, d_loss: inf ,  g_loss: inf,  db_loss: 1.7699
# Epoch : [38] ,  a_loss = 561.4442, d_loss: inf ,  g_loss: inf,  db_loss: 1.9491
# Epoch : [39] ,  a_loss = 384.4268, d_loss: inf ,  g_loss: inf,  db_loss: 1.3621
# Epoch : [40] ,  a_loss = 428.9091, d_loss: inf ,  g_loss: inf,  db_loss: 1.8318
# Epoch : [41] ,  a_loss = 588.0333, d_loss: inf ,  g_loss: inf,  db_loss: 1.8200
# Epoch : [42] ,  a_loss = 585.8199, d_loss: inf ,  g_loss: inf,  db_loss: 1.8108
# Epoch : [43] ,  a_loss = 353.5722, d_loss: inf ,  g_loss: inf,  db_loss: 1.6346
# Epoch : [44] ,  a_loss = 518.0524, d_loss: inf ,  g_loss: inf,  db_loss: 2.2860
# Epoch : [45] ,  a_loss = 569.0171, d_loss: inf ,  g_loss: inf,  db_loss: 1.9202
# Epoch : [46] ,  a_loss = 588.4967, d_loss: inf ,  g_loss: inf,  db_loss: 2.1893
# Epoch : [47] ,  a_loss = 575.1980, d_loss: inf ,  g_loss: inf,  db_loss: 1.7509
# Epoch : [48] ,  a_loss = 543.0974, d_loss: inf ,  g_loss: inf,  db_loss: 1.5746
# Epoch : [49] ,  a_loss = 600.9937, d_loss: inf ,  g_loss: inf,  db_loss: 2.0158
# Epoch : [50] ,  a_loss = 400.0464, d_loss: inf ,  g_loss: inf,  db_loss: 1.3845
# Epoch : [51] ,  a_loss = 612.9783, d_loss: inf ,  g_loss: inf,  db_loss: 1.3886
# Epoch : [52] ,  a_loss = 609.7295, d_loss: inf ,  g_loss: inf,  db_loss: 1.3956
# Epoch : [53] ,  a_loss = 381.6240, d_loss: inf ,  g_loss: inf,  db_loss: 1.1590
# Epoch : [54] ,  a_loss = 346.6575, d_loss: inf ,  g_loss: inf,  db_loss: 1.5543
# Epoch : [55] ,  a_loss = 312.8669, d_loss: inf ,  g_loss: inf,  db_loss: 1.1612
# Epoch : [56] ,  a_loss = 432.1956, d_loss: inf ,  g_loss: inf,  db_loss: 2.3113
# Epoch : [57] ,  a_loss = 332.5284, d_loss: inf ,  g_loss: inf,  db_loss: 0.9010
# Epoch : [58] ,  a_loss = 433.8714, d_loss: inf ,  g_loss: inf,  db_loss: 1.8745
# Epoch : [59] ,  a_loss = 562.2136, d_loss: inf ,  g_loss: inf,  db_loss: 1.7311
# Epoch : [60] ,  a_loss = 559.9720, d_loss: inf ,  g_loss: inf,  db_loss: 1.6624
# Epoch : [61] ,  a_loss = 309.8368, d_loss: inf ,  g_loss: inf,  db_loss: 1.7773
# Epoch : [62] ,  a_loss = 388.0512, d_loss: inf ,  g_loss: inf,  db_loss: 1.5392
# Epoch : [63] ,  a_loss = 427.7713, d_loss: inf ,  g_loss: inf,  db_loss: 2.3674
# Epoch : [64] ,  a_loss = 562.0529, d_loss: inf ,  g_loss: inf,  db_loss: 3.0419
# Epoch : [65] ,  a_loss = 417.1522, d_loss: inf ,  g_loss: inf,  db_loss: 2.0357
# Epoch : [66] ,  a_loss = 340.0029, d_loss: inf ,  g_loss: inf,  db_loss: 1.2350
# Epoch : [67] ,  a_loss = 564.8103, d_loss: inf ,  g_loss: inf,  db_loss: 3.0842
# Epoch : [68] ,  a_loss = 518.5312, d_loss: inf ,  g_loss: inf,  db_loss: 1.8572
# Epoch : [69] ,  a_loss = 421.9127, d_loss: inf ,  g_loss: inf,  db_loss: 1.8216
# Epoch : [70] ,  a_loss = 299.2902, d_loss: inf ,  g_loss: inf,  db_loss: 1.3024
# Epoch : [71] ,  a_loss = 576.3048, d_loss: inf ,  g_loss: inf,  db_loss: 1.8252
# Epoch : [72] ,  a_loss = 551.6275, d_loss: inf ,  g_loss: inf,  db_loss: 2.1097
# Epoch : [73] ,  a_loss = 401.4129, d_loss: inf ,  g_loss: inf,  db_loss: 2.3654
# Epoch : [74] ,  a_loss = 324.7505, d_loss: inf ,  g_loss: inf,  db_loss: 1.1925
# Epoch : [75] ,  a_loss = 398.0644, d_loss: inf ,  g_loss: inf,  db_loss: 2.1446
# Epoch : [76] ,  a_loss = 557.7267, d_loss: inf ,  g_loss: inf,  db_loss: 2.8920
# Epoch : [77] ,  a_loss = 393.1468, d_loss: inf ,  g_loss: inf,  db_loss: 2.1867
# Epoch : [78] ,  a_loss = 549.9203, d_loss: inf ,  g_loss: inf,  db_loss: 2.1072
# Epoch : [79] ,  a_loss = 588.6028, d_loss: inf ,  g_loss: inf,  db_loss: 1.9993
# Epoch : [80] ,  a_loss = 370.2047, d_loss: inf ,  g_loss: inf,  db_loss: 1.4286
# Epoch : [81] ,  a_loss = 506.1466, d_loss: inf ,  g_loss: inf,  db_loss: 1.9123
# Epoch : [82] ,  a_loss = 299.0585, d_loss: inf ,  g_loss: inf,  db_loss: 1.6873
# Epoch : [83] ,  a_loss = 332.8094, d_loss: inf ,  g_loss: inf,  db_loss: 1.9823
# Epoch : [84] ,  a_loss = 368.5114, d_loss: inf ,  g_loss: inf,  db_loss: 1.4011
# Epoch : [85] ,  a_loss = 544.4417, d_loss: inf ,  g_loss: inf,  db_loss: 1.9556
# Epoch : [86] ,  a_loss = 372.2667, d_loss: inf ,  g_loss: inf,  db_loss: 1.3598
# Epoch : [87] ,  a_loss = 584.7614, d_loss: inf ,  g_loss: inf,  db_loss: 1.9364
# Epoch : [88] ,  a_loss = 391.5193, d_loss: inf ,  g_loss: inf,  db_loss: 1.9250
# Epoch : [89] ,  a_loss = 577.1804, d_loss: inf ,  g_loss: inf,  db_loss: 1.1304
# Epoch : [90] ,  a_loss = 490.0790, d_loss: inf ,  g_loss: inf,  db_loss: 1.9711
# Epoch : [91] ,  a_loss = 569.4933, d_loss: inf ,  g_loss: inf,  db_loss: 2.4655
# Epoch : [92] ,  a_loss = 560.4983, d_loss: inf ,  g_loss: inf,  db_loss: 1.4101
# Epoch : [93] ,  a_loss = 565.1064, d_loss: inf ,  g_loss: inf,  db_loss: 2.6927
# Epoch : [94] ,  a_loss = 586.7142, d_loss: inf ,  g_loss: inf,  db_loss: 1.7892
# Epoch : [95] ,  a_loss = 389.2752, d_loss: inf ,  g_loss: inf,  db_loss: 1.7654
# Epoch : [96] ,  a_loss = 417.4746, d_loss: inf ,  g_loss: inf,  db_loss: 2.3493
# Epoch : [97] ,  a_loss = 503.6727, d_loss: inf ,  g_loss: inf,  db_loss: 1.6045
# Epoch : [98] ,  a_loss = 290.7247, d_loss: inf ,  g_loss: inf,  db_loss: 1.5879
# Epoch : [99] ,  a_loss = 370.5790, d_loss: inf ,  g_loss: inf,  db_loss: 2.3146
# Epoch : [100] ,  a_loss = 543.6319, d_loss: inf ,  g_loss: inf,  db_loss: 2.1050
# Epoch : [101] ,  a_loss = 349.1860, d_loss: inf ,  g_loss: inf,  db_loss: 1.9391
# Epoch : [102] ,  a_loss = 287.7009, d_loss: inf ,  g_loss: inf,  db_loss: 1.2101
# Epoch : [103] ,  a_loss = 424.8658, d_loss: inf ,  g_loss: inf,  db_loss: 2.4371
# Epoch : [104] ,  a_loss = 391.9128, d_loss: inf ,  g_loss: inf,  db_loss: 2.2824
# Epoch : [105] ,  a_loss = 507.6906, d_loss: inf ,  g_loss: inf,  db_loss: 1.6792
# Epoch : [106] ,  a_loss = 428.1261, d_loss: inf ,  g_loss: inf,  db_loss: 2.1030
# Epoch : [107] ,  a_loss = 371.0123, d_loss: inf ,  g_loss: inf,  db_loss: 1.8357
# Epoch : [108] ,  a_loss = 346.0394, d_loss: inf ,  g_loss: inf,  db_loss: 1.5132
# Epoch : [109] ,  a_loss = 372.4375, d_loss: inf ,  g_loss: inf,  db_loss: 1.9534
# Epoch : [110] ,  a_loss = 373.6220, d_loss: inf ,  g_loss: inf,  db_loss: 2.3867
# Epoch : [111] ,  a_loss = 346.9266, d_loss: inf ,  g_loss: inf,  db_loss: 1.6116
# Epoch : [112] ,  a_loss = 328.4867, d_loss: inf ,  g_loss: inf,  db_loss: 1.7267
# Epoch : [113] ,  a_loss = 470.8900, d_loss: inf ,  g_loss: inf,  db_loss: 2.4046
# Epoch : [114] ,  a_loss = 329.1446, d_loss: inf ,  g_loss: inf,  db_loss: 1.2698
# Epoch : [115] ,  a_loss = 343.2664, d_loss: inf ,  g_loss: inf,  db_loss: 1.6412
# Epoch : [116] ,  a_loss = 525.1048, d_loss: inf ,  g_loss: inf,  db_loss: 1.1730
# Epoch : [117] ,  a_loss = 321.2490, d_loss: inf ,  g_loss: inf,  db_loss: 0.9750
# Epoch : [118] ,  a_loss = 393.3763, d_loss: inf ,  g_loss: inf,  db_loss: 1.8092
# Epoch : [119] ,  a_loss = 325.6823, d_loss: inf ,  g_loss: inf,  db_loss: 1.5117
# Epoch : [120] ,  a_loss = 305.7957, d_loss: inf ,  g_loss: inf,  db_loss: 1.3245
# Epoch : [121] ,  a_loss = 301.3405, d_loss: inf ,  g_loss: inf,  db_loss: 1.1674
# Epoch : [122] ,  a_loss = 326.1418, d_loss: inf ,  g_loss: inf,  db_loss: 1.7340
# Epoch : [123] ,  a_loss = 537.3157, d_loss: inf ,  g_loss: inf,  db_loss: 1.8230
# Epoch : [124] ,  a_loss = 344.4809, d_loss: inf ,  g_loss: inf,  db_loss: 1.4114
# Epoch : [125] ,  a_loss = 289.6977, d_loss: inf ,  g_loss: inf,  db_loss: 1.2534
# Epoch : [126] ,  a_loss = 499.0163, d_loss: inf ,  g_loss: inf,  db_loss: 1.5989
# Epoch : [127] ,  a_loss = 314.4665, d_loss: inf ,  g_loss: inf,  db_loss: 1.3647
# Epoch : [128] ,  a_loss = 364.5472, d_loss: inf ,  g_loss: inf,  db_loss: 1.7442
# Epoch : [129] ,  a_loss = 506.5771, d_loss: inf ,  g_loss: inf,  db_loss: 1.6186
# Epoch : [130] ,  a_loss = 279.3404, d_loss: inf ,  g_loss: inf,  db_loss: 1.4270
# Epoch : [131] ,  a_loss = 340.0148, d_loss: inf ,  g_loss: inf,  db_loss: 0.8864
# Epoch : [132] ,  a_loss = 363.5586, d_loss: inf ,  g_loss: inf,  db_loss: 1.8032
# Epoch : [133] ,  a_loss = 355.7199, d_loss: inf ,  g_loss: inf,  db_loss: 1.4171
# Epoch : [134] ,  a_loss = 331.4323, d_loss: inf ,  g_loss: inf,  db_loss: 1.6135
# Epoch : [135] ,  a_loss = 540.3558, d_loss: inf ,  g_loss: inf,  db_loss: 1.8788
# Epoch : [136] ,  a_loss = 347.2601, d_loss: inf ,  g_loss: inf,  db_loss: 1.1680
# Epoch : [137] ,  a_loss = 458.9142, d_loss: inf ,  g_loss: inf,  db_loss: 1.6878
# Epoch : [138] ,  a_loss = 368.3629, d_loss: inf ,  g_loss: inf,  db_loss: 1.6006
# Epoch : [139] ,  a_loss = 554.2783, d_loss: inf ,  g_loss: inf,  db_loss: 1.8132
# Epoch : [140] ,  a_loss = 400.2655, d_loss: inf ,  g_loss: inf,  db_loss: 2.0676
# Epoch : [141] ,  a_loss = 522.7581, d_loss: inf ,  g_loss: inf,  db_loss: 2.2555
# Epoch : [142] ,  a_loss = 422.2194, d_loss: inf ,  g_loss: inf,  db_loss: 2.2195
# Epoch : [143] ,  a_loss = 382.5767, d_loss: inf ,  g_loss: inf,  db_loss: 1.4017
# Epoch : [144] ,  a_loss = 334.4720, d_loss: inf ,  g_loss: inf,  db_loss: 1.9452
# Epoch : [145] ,  a_loss = 405.7673, d_loss: inf ,  g_loss: inf,  db_loss: 1.8883
# Epoch : [146] ,  a_loss = 356.8423, d_loss: inf ,  g_loss: inf,  db_loss: 2.2086
# Epoch : [147] ,  a_loss = 365.2115, d_loss: inf ,  g_loss: inf,  db_loss: 2.3323
# Epoch : [148] ,  a_loss = 322.7092, d_loss: inf ,  g_loss: inf,  db_loss: 1.1056
# Epoch : [149] ,  a_loss = 340.0541, d_loss: inf ,  g_loss: inf,  db_loss: 1.0402
# Epoch : [150] ,  a_loss = 507.7597, d_loss: inf ,  g_loss: inf,  db_loss: 1.8188
# Epoch : [151] ,  a_loss = 504.3699, d_loss: inf ,  g_loss: inf,  db_loss: 1.8562
# Epoch : [152] ,  a_loss = 369.0566, d_loss: inf ,  g_loss: inf,  db_loss: 2.2564
# Epoch : [153] ,  a_loss = 533.9232, d_loss: inf ,  g_loss: inf,  db_loss: 1.6571
# Epoch : [154] ,  a_loss = 353.2869, d_loss: inf ,  g_loss: inf,  db_loss: 1.9278
# Epoch : [155] ,  a_loss = 485.4430, d_loss: inf ,  g_loss: inf,  db_loss: 2.0679
# Epoch : [156] ,  a_loss = 399.8942, d_loss: inf ,  g_loss: inf,  db_loss: 2.1173
# Epoch : [157] ,  a_loss = 475.4727, d_loss: inf ,  g_loss: inf,  db_loss: 2.0475
# Epoch : [158] ,  a_loss = 358.4174, d_loss: inf ,  g_loss: inf,  db_loss: 1.9676
# Epoch : [159] ,  a_loss = 426.9170, d_loss: inf ,  g_loss: inf,  db_loss: 2.3238
# Epoch : [160] ,  a_loss = 349.0700, d_loss: inf ,  g_loss: inf,  db_loss: 1.0448
# Epoch : [161] ,  a_loss = 329.4027, d_loss: inf ,  g_loss: inf,  db_loss: 1.3578
# Epoch : [162] ,  a_loss = 340.0569, d_loss: inf ,  g_loss: inf,  db_loss: 1.4915
# Epoch : [163] ,  a_loss = 371.2813, d_loss: inf ,  g_loss: inf,  db_loss: 2.6868
# Epoch : [164] ,  a_loss = 400.0783, d_loss: inf ,  g_loss: inf,  db_loss: 2.6248
# Epoch : [165] ,  a_loss = 461.0040, d_loss: inf ,  g_loss: inf,  db_loss: 2.9517
# Epoch : [166] ,  a_loss = 523.0426, d_loss: inf ,  g_loss: inf,  db_loss: 2.4147
# Epoch : [167] ,  a_loss = 348.0215, d_loss: inf ,  g_loss: inf,  db_loss: 1.3893
# Epoch : [168] ,  a_loss = 410.7487, d_loss: inf ,  g_loss: inf,  db_loss: 2.1680
# Epoch : [169] ,  a_loss = 486.5401, d_loss: inf ,  g_loss: inf,  db_loss: 2.3389
# Epoch : [170] ,  a_loss = 433.2779, d_loss: inf ,  g_loss: inf,  db_loss: 1.7550
# Epoch : [171] ,  a_loss = 355.3363, d_loss: inf ,  g_loss: inf,  db_loss: 1.9871
# Epoch : [172] ,  a_loss = 317.2519, d_loss: inf ,  g_loss: inf,  db_loss: 1.4981
# Epoch : [173] ,  a_loss = 486.1141, d_loss: inf ,  g_loss: inf,  db_loss: 2.7919
# Epoch : [174] ,  a_loss = 330.9844, d_loss: inf ,  g_loss: inf,  db_loss: 1.6474
# Epoch : [175] ,  a_loss = 361.2013, d_loss: inf ,  g_loss: inf,  db_loss: 2.0137
# Epoch : [176] ,  a_loss = 350.1206, d_loss: inf ,  g_loss: inf,  db_loss: 2.1577
# Epoch : [177] ,  a_loss = 510.6207, d_loss: inf ,  g_loss: inf,  db_loss: 2.7014
# Epoch : [178] ,  a_loss = 501.4599, d_loss: inf ,  g_loss: inf,  db_loss: 1.5842
# Epoch : [179] ,  a_loss = 531.7820, d_loss: inf ,  g_loss: inf,  db_loss: 1.1549
# Epoch : [180] ,  a_loss = 325.7852, d_loss: inf ,  g_loss: inf,  db_loss: 1.3121
# Epoch : [181] ,  a_loss = 500.8967, d_loss: inf ,  g_loss: inf,  db_loss: 1.5670
# Epoch : [182] ,  a_loss = 529.8713, d_loss: inf ,  g_loss: inf,  db_loss: 1.6903
# Epoch : [183] ,  a_loss = 335.8722, d_loss: inf ,  g_loss: inf,  db_loss: 1.4762
# Epoch : [184] ,  a_loss = 331.1815, d_loss: inf ,  g_loss: inf,  db_loss: 1.5905
# Epoch : [185] ,  a_loss = 454.9491, d_loss: inf ,  g_loss: inf,  db_loss: 2.4136
# Epoch : [186] ,  a_loss = 464.6155, d_loss: inf ,  g_loss: inf,  db_loss: 3.1713
# Epoch : [187] ,  a_loss = 560.4520, d_loss: inf ,  g_loss: inf,  db_loss: 1.7327
# Epoch : [188] ,  a_loss = 480.4678, d_loss: inf ,  g_loss: inf,  db_loss: 1.5741
# Epoch : [189] ,  a_loss = 333.9603, d_loss: inf ,  g_loss: inf,  db_loss: 1.4790
# Epoch : [190] ,  a_loss = 379.2346, d_loss: inf ,  g_loss: inf,  db_loss: 2.0447
# Epoch : [191] ,  a_loss = 497.2350, d_loss: inf ,  g_loss: inf,  db_loss: 1.4220
# Epoch : [192] ,  a_loss = 502.7773, d_loss: inf ,  g_loss: inf,  db_loss: 2.7465
# Epoch : [193] ,  a_loss = 335.4429, d_loss: inf ,  g_loss: inf,  db_loss: 2.3414
# Epoch : [194] ,  a_loss = 458.6955, d_loss: inf ,  g_loss: inf,  db_loss: 1.6993
# Epoch : [195] ,  a_loss = 537.6335, d_loss: inf ,  g_loss: inf,  db_loss: 1.3085
# Epoch : [196] ,  a_loss = 320.1063, d_loss: inf ,  g_loss: inf,  db_loss: 1.7359
# Epoch : [197] ,  a_loss = 315.4462, d_loss: inf ,  g_loss: inf,  db_loss: 1.2978
# Epoch : [198] ,  a_loss = 283.6385, d_loss: inf ,  g_loss: inf,  db_loss: 1.1089
# Epoch : [199] ,  a_loss = 541.7712, d_loss: inf ,  g_loss: inf,  db_loss: 1.9815
# Epoch : [200] ,  a_loss = 538.5046, d_loss: inf ,  g_loss: inf,  db_loss: 1.4893
# Epoch : [201] ,  a_loss = 465.7971, d_loss: inf ,  g_loss: inf,  db_loss: 1.9587
# Epoch : [202] ,  a_loss = 530.1815, d_loss: inf ,  g_loss: inf,  db_loss: 2.2761
# Epoch : [203] ,  a_loss = 361.6280, d_loss: inf ,  g_loss: inf,  db_loss: 1.7225
# Epoch : [204] ,  a_loss = 334.0424, d_loss: inf ,  g_loss: inf,  db_loss: 2.0183
# Epoch : [205] ,  a_loss = 503.9063, d_loss: inf ,  g_loss: inf,  db_loss: 2.2804
# Epoch : [206] ,  a_loss = 544.1268, d_loss: inf ,  g_loss: inf,  db_loss: 1.8362
# Epoch : [207] ,  a_loss = 547.4755, d_loss: inf ,  g_loss: inf,  db_loss: 1.4362
# Epoch : [208] ,  a_loss = 335.4759, d_loss: inf ,  g_loss: inf,  db_loss: 1.4356
# Epoch : [209] ,  a_loss = 541.8530, d_loss: inf ,  g_loss: inf,  db_loss: 2.0353
# Epoch : [210] ,  a_loss = 486.8860, d_loss: inf ,  g_loss: inf,  db_loss: 1.5339
# Epoch : [211] ,  a_loss = 364.7216, d_loss: inf ,  g_loss: inf,  db_loss: 1.1425
# Epoch : [212] ,  a_loss = 292.6492, d_loss: inf ,  g_loss: inf,  db_loss: 1.1464
# Epoch : [213] ,  a_loss = 351.2914, d_loss: inf ,  g_loss: inf,  db_loss: 1.5335
# Epoch : [214] ,  a_loss = 335.4715, d_loss: inf ,  g_loss: inf,  db_loss: 1.4243
# Epoch : [215] ,  a_loss = 465.3259, d_loss: inf ,  g_loss: inf,  db_loss: 1.7660
# Epoch : [216] ,  a_loss = 555.5557, d_loss: inf ,  g_loss: inf,  db_loss: 1.4339
# Epoch : [217] ,  a_loss = 522.9313, d_loss: inf ,  g_loss: inf,  db_loss: 1.9129
# Epoch : [218] ,  a_loss = 414.1887, d_loss: inf ,  g_loss: inf,  db_loss: 2.2477
# Epoch : [219] ,  a_loss = 399.6632, d_loss: inf ,  g_loss: inf,  db_loss: 2.0969
# Epoch : [220] ,  a_loss = 342.2004, d_loss: inf ,  g_loss: inf,  db_loss: 1.2981
# Epoch : [221] ,  a_loss = 305.7874, d_loss: inf ,  g_loss: inf,  db_loss: 1.3447
# Epoch : [222] ,  a_loss = 455.0988, d_loss: inf ,  g_loss: inf,  db_loss: 2.4131
# Epoch : [223] ,  a_loss = 332.6472, d_loss: inf ,  g_loss: inf,  db_loss: 1.6590
# Epoch : [224] ,  a_loss = 441.4582, d_loss: inf ,  g_loss: inf,  db_loss: 2.4811
# Epoch : [225] ,  a_loss = 540.3047, d_loss: inf ,  g_loss: inf,  db_loss: 1.6137
# Epoch : [226] ,  a_loss = 374.4876, d_loss: inf ,  g_loss: inf,  db_loss: 2.6143
# Epoch : [227] ,  a_loss = 349.8843, d_loss: inf ,  g_loss: inf,  db_loss: 2.4632
# Epoch : [228] ,  a_loss = 321.5382, d_loss: inf ,  g_loss: inf,  db_loss: 1.6299
# Epoch : [229] ,  a_loss = 372.3788, d_loss: inf ,  g_loss: inf,  db_loss: 1.9860
# Epoch : [230] ,  a_loss = 482.2946, d_loss: inf ,  g_loss: inf,  db_loss: 1.6597
# Epoch : [231] ,  a_loss = 416.0907, d_loss: inf ,  g_loss: inf,  db_loss: 2.3177
# Epoch : [232] ,  a_loss = 502.9773, d_loss: inf ,  g_loss: inf,  db_loss: 2.4104
# Epoch : [233] ,  a_loss = 350.3358, d_loss: inf ,  g_loss: inf,  db_loss: 1.8997
# Epoch : [234] ,  a_loss = 411.9659, d_loss: inf ,  g_loss: inf,  db_loss: 2.2224
# Epoch : [235] ,  a_loss = 523.8796, d_loss: inf ,  g_loss: inf,  db_loss: 1.8749
# Epoch : [236] ,  a_loss = 545.8181, d_loss: inf ,  g_loss: inf,  db_loss: 1.4312
# Epoch : [237] ,  a_loss = 404.0847, d_loss: inf ,  g_loss: inf,  db_loss: 2.0914
# Epoch : [238] ,  a_loss = 529.5135, d_loss: inf ,  g_loss: inf,  db_loss: 2.4452
# Epoch : [239] ,  a_loss = 375.0039, d_loss: inf ,  g_loss: inf,  db_loss: 2.0859
# Epoch : [240] ,  a_loss = 556.8143, d_loss: inf ,  g_loss: inf,  db_loss: 1.6603
# Epoch : [241] ,  a_loss = 351.4565, d_loss: inf ,  g_loss: inf,  db_loss: 2.0458
# Epoch : [242] ,  a_loss = 462.2257, d_loss: inf ,  g_loss: inf,  db_loss: 1.9521
# Epoch : [243] ,  a_loss = 310.2401, d_loss: inf ,  g_loss: inf,  db_loss: 1.6490
# Epoch : [244] ,  a_loss = 353.1776, d_loss: inf ,  g_loss: inf,  db_loss: 2.4136
# Epoch : [245] ,  a_loss = 515.9193, d_loss: inf ,  g_loss: inf,  db_loss: 2.4905
# Epoch : [246] ,  a_loss = 538.0496, d_loss: inf ,  g_loss: inf,  db_loss: 1.3609
# Epoch : [247] ,  a_loss = 455.2751, d_loss: inf ,  g_loss: inf,  db_loss: 1.5380
# Epoch : [248] ,  a_loss = 338.2372, d_loss: inf ,  g_loss: inf,  db_loss: 2.1394
# Epoch : [249] ,  a_loss = 509.8049, d_loss: inf ,  g_loss: inf,  db_loss: 2.2839
# latent_matrix shape (16382, 10)
# (16382,)
# None
# None
# Computing NMI ...
# Done !
# NMI = 0.7409972997347504
