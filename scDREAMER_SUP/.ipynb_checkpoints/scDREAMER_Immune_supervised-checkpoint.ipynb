# %% [markdown]
# <a href="https://colab.research.google.com/github/Zafar-Lab/scDREAMER/blob/main/2109_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 
import random
import numpy as np
import tensorflow as tf2
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# 2023-05-11 15:12:35.708836: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-11 15:12:36.753141: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
#tf.enable_eager_execution()
np.random.seed(0)
#tf.set_random_seed(0)
tf.set_random_seed(0)
random.seed(0)
tf2.random.set_seed(0)
tf2.keras.utils.set_random_seed(0)
#tf.keras.utils.set_random_seed(0)

# %%
import warnings
warnings.filterwarnings('ignore')
"""
# !pip install -U scipy==1.5.0
# !pip install scanpy==1.8.2
# !pip install -U scikit-learn
"""
# Out:
# '\n!pip install -U scipy==1.5.0\n!pip install scanpy==1.8.2\n!pip install -U scikit-learn\n'

# %% [markdown]
# Building model

# %%
data_path = "/home/ajita/Documents/data_integration/Immune/Immune_Human.h5ad"
#data_path = "/home/ajita/Documents/data_integration/Immune/Immune_Human_NA_0.5.h5ad"

# %%
name = "Immune_Human"

batch_key_dic = {'Immune_Human' : 'batch',
                 'Lung' : 'batch',
                 'Pancreas' : 'tech',
                 'Human_Mouse' : 'batch',
                 'Human_Retina': "Batch"
                 
                }

# Below dictionary is an input to model for available cell types.
cell_type_key_dict = {'Immune_Human' : 'final_annotation',
                 'Lung' : 'cell_type',
                 'Pancreas' : 'celltype',
                 'Human_Mouse' : "celltype",
                 "Human_Retina":"Subcluster"
                    } 
    
plot_cell_type_dict = {
                    "Healthy_Heart" : "celltype",
                    'Immune_Human' : 'final_annotation', #'final_annotation',
                 'Lung' : 'cell_type',
                 'Pancreas' : 'celltype',
                 'Human_Mouse' : "celltype",
                 "Human_Retina":"Subcluster"
                    }

# %%
import src_shuffle.model_scdreamer_semisupervised as model

run_config = tf.ConfigProto()

run_config.gpu_options.per_process_gpu_memory_fraction = 0.333
run_config.gpu_options.allow_growth = True

with tf.Session(config = run_config) as sess:

    dreamer = model.scDREAMER(
        sess,
        epoch = 300,
        dataset_name = data_path,
        batch = batch_key_dic[name],
        cell_type = cell_type_key_dict[name],
        plot_cell_type = plot_cell_type_dict[name],
        name = name
        )

    dreamer.train_cluster()
# Out:
# 2023-05-11 15:12:40.703852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5367 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:d8:00.0, compute capability: 7.5
# Loading dataset
# Preprocessing...
# here [2 4 1 ... 1 2 2]
# Shape self.data_train: (33506, 2000)
# Shape self.data_test: (33506, 2000)
# encoder input shape  Tensor("concat:0", shape=(?, 2010), dtype=float32)
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# decoder input shape  Tensor("concat_2:0", shape=(?, 20), dtype=float32)
# inferred check Tensor("Max:0", shape=(), dtype=float32)
# entering in for loop 1   512  -- > 256
# KL gaussian z Tensor("mul_13:0", shape=(?,), dtype=float32)
# KL gaussian l Tensor("mul_12:0", shape=(?,), dtype=float32)
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Cluster DRA on DataSet /home/ajita/Documents/data_integration/Immune/Immune_Human.h5ad ...
# 2023-05-11 15:13:02.915712: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# Epoch : [0] ,  a_loss = 378.6133, d_loss: -0.3901 , db_loss: 2.1148
# latent_matrix shape (33506, 10)
# (33506,)
# None
# None
# Computing NMI ...
# Done !
# NMI = 0.5664516322034885
# Epoch : [1] ,  a_loss = 347.8450, d_loss: -0.1294 , db_loss: 3.1278
# Epoch : [2] ,  a_loss = 465.7111, d_loss: -0.0762 , db_loss: 1.0633
# Epoch : [3] ,  a_loss = 390.8611, d_loss: -0.0117 , db_loss: 2.5593
# Epoch : [4] ,  a_loss = 339.0439, d_loss: -0.0194 , db_loss: 1.4953
# Epoch : [5] ,  a_loss = 334.5034, d_loss: -0.0242 , db_loss: 2.4429
# Epoch : [6] ,  a_loss = 458.7752, d_loss: -0.0270 , db_loss: 0.9390
# Epoch : [7] ,  a_loss = 331.9075, d_loss: -0.3514 , db_loss: 1.8232
# Epoch : [8] ,  a_loss = 436.2513, d_loss: -0.1296 , db_loss: 0.9004
# Epoch : [9] ,  a_loss = 421.2316, d_loss: -0.2191 , db_loss: 1.2616
# Epoch : [10] ,  a_loss = 363.0315, d_loss: -0.0276 , db_loss: 1.7194
# Epoch : [11] ,  a_loss = 332.1170, d_loss: -0.0060 , db_loss: 1.8162
# Epoch : [12] ,  a_loss = 408.5872, d_loss: 0.0301 , db_loss: 1.0188
# Epoch : [13] ,  a_loss = 398.2292, d_loss: -0.0221 , db_loss: 0.5682
# Epoch : [14] ,  a_loss = 451.3056, d_loss: -0.0028 , db_loss: 0.8251
# Epoch : [15] ,  a_loss = 359.9099, d_loss: -0.0063 , db_loss: 1.7342
# Epoch : [16] ,  a_loss = 346.2830, d_loss: -0.0080 , db_loss: 2.0215
# Epoch : [17] ,  a_loss = 437.4207, d_loss: -0.0029 , db_loss: 0.9694
# Epoch : [18] ,  a_loss = 429.6698, d_loss: -0.0022 , db_loss: 0.6520
# Epoch : [19] ,  a_loss = 555.6937, d_loss: -0.0024 , db_loss: 0.1822
# Epoch : [20] ,  a_loss = 442.5741, d_loss: -0.0031 , db_loss: 0.6946
# Epoch : [21] ,  a_loss = 425.4926, d_loss: -0.0040 , db_loss: 0.8056
# Epoch : [22] ,  a_loss = 427.6322, d_loss: -0.0082 , db_loss: 1.0446
# Epoch : [23] ,  a_loss = 305.3768, d_loss: -0.0643 , db_loss: 2.7426
# Epoch : [24] ,  a_loss = 290.7171, d_loss: -0.0111 , db_loss: 2.1941
# Epoch : [25] ,  a_loss = 292.7021, d_loss: -0.0089 , db_loss: 2.8700
# Epoch : [26] ,  a_loss = 425.6483, d_loss: -0.0336 , db_loss: 0.8487
# Epoch : [27] ,  a_loss = 420.8398, d_loss: -0.0080 , db_loss: 0.8107
# Epoch : [28] ,  a_loss = 423.5825, d_loss: -0.0112 , db_loss: 0.7258
# Epoch : [29] ,  a_loss = 288.9520, d_loss: -0.0122 , db_loss: 2.4014
# Epoch : [30] ,  a_loss = 294.4962, d_loss: -0.2071 , db_loss: 2.3622
# Epoch : [31] ,  a_loss = 350.1340, d_loss: -0.4352 , db_loss: 2.0281
# Epoch : [32] ,  a_loss = 377.7113, d_loss: -0.6654 , db_loss: 0.9730
# Epoch : [33] ,  a_loss = 295.8602, d_loss: -1.0263 , db_loss: 2.2428
# Epoch : [34] ,  a_loss = 280.1574, d_loss: -1.0323 , db_loss: 2.7547
# Epoch : [35] ,  a_loss = 373.4433, d_loss: -0.8351 , db_loss: 2.0243
# Epoch : [36] ,  a_loss = 410.1164, d_loss: -1.0188 , db_loss: 0.6051
# Epoch : [37] ,  a_loss = 297.7505, d_loss: -0.9822 , db_loss: 2.2021
# Epoch : [38] ,  a_loss = 417.3199, d_loss: -1.2174 , db_loss: 1.1046
# Epoch : [39] ,  a_loss = 408.6465, d_loss: -1.1106 , db_loss: 1.1192
# Epoch : [40] ,  a_loss = 420.8486, d_loss: -1.3934 , db_loss: 0.7785
# Epoch : [41] ,  a_loss = 409.4505, d_loss: -1.3921 , db_loss: 0.5914
# Epoch : [42] ,  a_loss = 417.0933, d_loss: -1.5147 , db_loss: 0.8714
# Epoch : [43] ,  a_loss = 532.8303, d_loss: -0.3906 , db_loss: 0.0329
# Epoch : [44] ,  a_loss = 349.3662, d_loss: -1.0827 , db_loss: 2.1922
# Epoch : [45] ,  a_loss = 292.4281, d_loss: -1.8380 , db_loss: 2.9044
# Epoch : [46] ,  a_loss = 413.8731, d_loss: -1.0699 , db_loss: 0.8121
# Epoch : [47] ,  a_loss = 272.4834, d_loss: -1.5045 , db_loss: 2.5306
# Epoch : [48] ,  a_loss = 362.2286, d_loss: -1.0976 , db_loss: 1.2906
# Epoch : [49] ,  a_loss = 296.4176, d_loss: -1.1574 , db_loss: 1.8938
# Epoch : [50] ,  a_loss = 397.1402, d_loss: -0.9375 , db_loss: 0.8018
# latent_matrix shape (33506, 10)
# (33506,)
# None
# None
# Computing NMI ...
# Done !
# NMI = 0.8463426911254558
# Epoch : [51] ,  a_loss = 301.3416, d_loss: -1.1298 , db_loss: 2.0961
# Epoch : [52] ,  a_loss = 361.3333, d_loss: -0.9933 , db_loss: 1.1493
# Epoch : [53] ,  a_loss = 557.1654, d_loss: -1.4732 , db_loss: 0.7186
# Epoch : [54] ,  a_loss = 277.9568, d_loss: -1.8699 , db_loss: 2.4440
# Epoch : [55] ,  a_loss = 294.5363, d_loss: -0.6695 , db_loss: 2.3975
# Epoch : [56] ,  a_loss = 303.4318, d_loss: -1.0791 , db_loss: 1.7304
# Epoch : [57] ,  a_loss = 282.4508, d_loss: -2.1157 , db_loss: 2.3919
# Epoch : [58] ,  a_loss = 272.6039, d_loss: -1.3926 , db_loss: 2.2979
# Epoch : [59] ,  a_loss = 405.1909, d_loss: -1.0394 , db_loss: 0.7255
# Epoch : [60] ,  a_loss = 284.9189, d_loss: -1.4229 , db_loss: 2.1240
# Epoch : [61] ,  a_loss = 407.1879, d_loss: -1.2016 , db_loss: 0.9235
# Epoch : [62] ,  a_loss = 395.6443, d_loss: -1.7869 , db_loss: 0.8599
# Epoch : [63] ,  a_loss = 356.9797, d_loss: -1.0328 , db_loss: 1.4605
# Epoch : [64] ,  a_loss = 406.8729, d_loss: -1.3917 , db_loss: 0.7110
# Epoch : [65] ,  a_loss = 405.4387, d_loss: -1.3128 , db_loss: 0.9821
# Epoch : [66] ,  a_loss = 291.2134, d_loss: -0.8045 , db_loss: 2.0268
# Epoch : [67] ,  a_loss = 278.4362, d_loss: -1.8344 , db_loss: 2.6688
# Epoch : [68] ,  a_loss = 397.4535, d_loss: -0.4689 , db_loss: 0.9707
# Epoch : [69] ,  a_loss = 293.0234, d_loss: -0.4569 , db_loss: 2.1991
# Epoch : [70] ,  a_loss = 295.5769, d_loss: -1.6180 , db_loss: 2.0695
# Epoch : [71] ,  a_loss = 299.9215, d_loss: -0.4980 , db_loss: 2.1024
# Epoch : [72] ,  a_loss = 270.6496, d_loss: -0.7329 , db_loss: 2.1862
# Epoch : [73] ,  a_loss = 332.7043, d_loss: -0.4993 , db_loss: 1.9054
# Epoch : [74] ,  a_loss = 285.7314, d_loss: -0.0279 , db_loss: 2.7234
# Epoch : [75] ,  a_loss = 310.5949, d_loss: -0.0265 , db_loss: 2.4637
# Epoch : [76] ,  a_loss = 335.0704, d_loss: -0.0138 , db_loss: 1.8432
# Epoch : [77] ,  a_loss = 401.8404, d_loss: -0.0341 , db_loss: 1.0453
# Epoch : [78] ,  a_loss = 347.9359, d_loss: -0.0295 , db_loss: 1.1701
# Epoch : [79] ,  a_loss = 391.5306, d_loss: -0.0206 , db_loss: 0.8157
# Epoch : [80] ,  a_loss = 379.5883, d_loss: -0.0352 , db_loss: 1.0662
# Epoch : [81] ,  a_loss = 292.8283, d_loss: -0.0314 , db_loss: 2.3192
# Epoch : [82] ,  a_loss = 402.6187, d_loss: -0.0308 , db_loss: 0.9862
# Epoch : [83] ,  a_loss = 348.5940, d_loss: -0.2984 , db_loss: 1.0446
# Epoch : [84] ,  a_loss = 276.2904, d_loss: -0.2779 , db_loss: 2.7422
# Epoch : [85] ,  a_loss = 386.4662, d_loss: -0.3488 , db_loss: 1.0678
# Epoch : [86] ,  a_loss = 274.4204, d_loss: -0.4322 , db_loss: 2.3857
# Epoch : [87] ,  a_loss = 297.7545, d_loss: -0.4287 , db_loss: 2.6085
# Epoch : [88] ,  a_loss = 468.2553, d_loss: -0.4876 , db_loss: 0.4844
# Epoch : [89] ,  a_loss = 384.9191, d_loss: -0.5306 , db_loss: 0.9236
# Epoch : [90] ,  a_loss = 308.8788, d_loss: -0.6002 , db_loss: 1.9140
# Epoch : [91] ,  a_loss = 276.9728, d_loss: -0.5986 , db_loss: 2.2777
# Epoch : [92] ,  a_loss = 274.3153, d_loss: -1.3278 , db_loss: 2.2782
# Epoch : [93] ,  a_loss = 340.6194, d_loss: -0.8535 , db_loss: 0.9926
# Epoch : [94] ,  a_loss = 283.1848, d_loss: -0.9490 , db_loss: 2.5526
# Epoch : [95] ,  a_loss = 391.8231, d_loss: -1.4426 , db_loss: 0.9067
# Epoch : [96] ,  a_loss = 307.4312, d_loss: -1.1563 , db_loss: 2.0562
# Epoch : [97] ,  a_loss = 284.0867, d_loss: -1.1434 , db_loss: 2.2719
# Epoch : [98] ,  a_loss = 318.2519, d_loss: 1.2627 , db_loss: 2.1319
# Epoch : [99] ,  a_loss = 391.5977, d_loss: -0.4685 , db_loss: 0.9700
# Epoch : [100] ,  a_loss = 380.2310, d_loss: 0.6025 , db_loss: 1.1500
# latent_matrix shape (33506, 10)
# (33506,)
# None
# None
# Computing NMI ...
# Done !
# NMI = 0.861288705816551
# Epoch : [101] ,  a_loss = 393.5099, d_loss: -0.0125 , db_loss: 0.9813
# Epoch : [102] ,  a_loss = 328.0479, d_loss: -0.0131 , db_loss: 2.2433
# Epoch : [103] ,  a_loss = 381.4721, d_loss: -0.0153 , db_loss: 0.9344
# Epoch : [104] ,  a_loss = 280.0486, d_loss: -0.0212 , db_loss: 2.5187
# Epoch : [105] ,  a_loss = 387.1465, d_loss: -0.0133 , db_loss: 0.8698
# Epoch : [106] ,  a_loss = 381.6074, d_loss: -0.0185 , db_loss: 0.8875
# Epoch : [107] ,  a_loss = 386.8344, d_loss: -0.0118 , db_loss: 0.8355
# Epoch : [108] ,  a_loss = 347.9557, d_loss: -0.0359 , db_loss: 1.2982
# Epoch : [109] ,  a_loss = 339.5886, d_loss: -0.0237 , db_loss: 1.4005
# Epoch : [110] ,  a_loss = 330.0988, d_loss: -0.0334 , db_loss: 1.4131
# Epoch : [111] ,  a_loss = 389.8823, d_loss: -0.0383 , db_loss: 0.8016
# Epoch : [112] ,  a_loss = 383.9902, d_loss: -0.0312 , db_loss: 1.1247
# Epoch : [113] ,  a_loss = 278.2938, d_loss: -0.0462 , db_loss: 2.1271
# Epoch : [114] ,  a_loss = 314.7566, d_loss: -0.0480 , db_loss: 2.2643
# Epoch : [115] ,  a_loss = 280.5335, d_loss: -0.0663 , db_loss: 1.9104
# Epoch : [116] ,  a_loss = 328.0190, d_loss: -0.0492 , db_loss: 1.7335
# Epoch : [117] ,  a_loss = 387.0738, d_loss: -0.0664 , db_loss: 0.9537
# Epoch : [118] ,  a_loss = 351.7677, d_loss: -0.0504 , db_loss: 1.1906
# Epoch : [119] ,  a_loss = 278.5451, d_loss: -0.0639 , db_loss: 1.9248
# Epoch : [120] ,  a_loss = 382.9132, d_loss: -0.1036 , db_loss: 0.9187
# Epoch : [121] ,  a_loss = 396.0776, d_loss: -0.0613 , db_loss: 0.9544
# Epoch : [122] ,  a_loss = 265.3620, d_loss: -0.0757 , db_loss: 2.6146
# Epoch : [123] ,  a_loss = 388.5201, d_loss: -0.0786 , db_loss: 0.9605
# Epoch : [124] ,  a_loss = 385.4847, d_loss: -0.0718 , db_loss: 1.2184
# Epoch : [125] ,  a_loss = 311.0395, d_loss: -0.0738 , db_loss: 2.3682
# Epoch : [126] ,  a_loss = 270.6747, d_loss: -0.0748 , db_loss: 2.2342
# Epoch : [127] ,  a_loss = 388.5376, d_loss: -0.0844 , db_loss: 1.0769
# Epoch : [128] ,  a_loss = 288.6897, d_loss: -0.0539 , db_loss: 2.1292
# Epoch : [129] ,  a_loss = 338.5688, d_loss: -0.0538 , db_loss: 1.0763
# Epoch : [130] ,  a_loss = 384.9624, d_loss: -0.0685 , db_loss: 0.7841
# Epoch : [131] ,  a_loss = 287.5624, d_loss: -0.0757 , db_loss: 1.6919
# Epoch : [132] ,  a_loss = 386.5667, d_loss: -0.0480 , db_loss: 1.0345
# Epoch : [133] ,  a_loss = 275.8999, d_loss: -0.0793 , db_loss: 2.6534
# Epoch : [134] ,  a_loss = 385.9213, d_loss: -0.0703 , db_loss: 1.0887
# Epoch : [135] ,  a_loss = 390.2909, d_loss: -0.0806 , db_loss: 0.9109
# Epoch : [136] ,  a_loss = 388.2511, d_loss: -0.0814 , db_loss: 0.7382
# Epoch : [137] ,  a_loss = 274.4964, d_loss: -0.1107 , db_loss: 2.3433
# Epoch : [138] ,  a_loss = 288.4305, d_loss: -0.0907 , db_loss: 2.4760
# Epoch : [139] ,  a_loss = 530.4055, d_loss: -0.0509 , db_loss: 1.2591
# Epoch : [140] ,  a_loss = 346.5524, d_loss: -0.0672 , db_loss: 1.1569
# Epoch : [141] ,  a_loss = 372.8175, d_loss: -0.0893 , db_loss: 1.0087
# Epoch : [142] ,  a_loss = 383.6158, d_loss: -0.0933 , db_loss: 1.1619
# Epoch : [143] ,  a_loss = 344.2092, d_loss: -0.0732 , db_loss: 1.0504
# Epoch : [144] ,  a_loss = 380.1996, d_loss: -0.1439 , db_loss: 1.0638
# Epoch : [145] ,  a_loss = 341.3279, d_loss: -0.0975 , db_loss: 1.3798
# Epoch : [146] ,  a_loss = 288.2183, d_loss: -0.1208 , db_loss: 2.6053
# Epoch : [147] ,  a_loss = 269.7607, d_loss: -0.0842 , db_loss: 2.4651
# Epoch : [148] ,  a_loss = 266.5876, d_loss: -0.0831 , db_loss: 2.0055
# Epoch : [149] ,  a_loss = 349.5708, d_loss: -0.0765 , db_loss: 1.1139
# Epoch : [150] ,  a_loss = 379.0037, d_loss: -0.1642 , db_loss: 0.9186
# latent_matrix shape (33506, 10)
# (33506,)
# None
# None
# Computing NMI ...
# Done !
# NMI = 0.8707497988614176
# Epoch : [151] ,  a_loss = 258.7922, d_loss: -0.0938 , db_loss: 2.6309
# Epoch : [152] ,  a_loss = 273.0610, d_loss: -0.1162 , db_loss: 2.4328
# Epoch : [153] ,  a_loss = 342.9355, d_loss: -0.1161 , db_loss: 1.6892
# Epoch : [154] ,  a_loss = 291.4282, d_loss: -0.1063 , db_loss: 2.8454
# Epoch : [155] ,  a_loss = 271.6010, d_loss: -0.1690 , db_loss: 2.2645
# Epoch : [156] ,  a_loss = 284.2262, d_loss: -0.1364 , db_loss: 2.4119
# Epoch : [157] ,  a_loss = 393.0504, d_loss: -0.1302 , db_loss: 0.9540
# Epoch : [158] ,  a_loss = 282.3670, d_loss: -0.2052 , db_loss: 2.3747
# Epoch : [159] ,  a_loss = 392.5763, d_loss: -0.1820 , db_loss: 0.8471
# Epoch : [160] ,  a_loss = 388.6003, d_loss: -0.2005 , db_loss: 0.7838
# Epoch : [161] ,  a_loss = 379.1209, d_loss: -0.2052 , db_loss: 0.8396
# Epoch : [162] ,  a_loss = 263.1231, d_loss: -0.2257 , db_loss: 2.4165
# Epoch : [163] ,  a_loss = 336.4748, d_loss: -0.1742 , db_loss: 1.5476
# Epoch : [164] ,  a_loss = 287.1190, d_loss: -0.1874 , db_loss: 2.6621
# Epoch : [165] ,  a_loss = 264.6916, d_loss: -0.2038 , db_loss: 2.2894
# Epoch : [166] ,  a_loss = 315.0042, d_loss: -0.1619 , db_loss: 1.9988
# Epoch : [167] ,  a_loss = 276.6276, d_loss: -0.1827 , db_loss: 2.4367
# Epoch : [168] ,  a_loss = 286.7453, d_loss: -0.1796 , db_loss: 1.9184
# Epoch : [169] ,  a_loss = 305.1653, d_loss: -0.1684 , db_loss: 1.9963
# Epoch : [170] ,  a_loss = 297.6115, d_loss: -0.2432 , db_loss: 2.0273
# Epoch : [171] ,  a_loss = 391.9699, d_loss: -0.1868 , db_loss: 0.9009
# Epoch : [172] ,  a_loss = 343.3149, d_loss: -0.2000 , db_loss: 1.2356
# Epoch : [173] ,  a_loss = 379.8788, d_loss: -0.2006 , db_loss: 1.0633
# Epoch : [174] ,  a_loss = 275.7713, d_loss: -0.2290 , db_loss: 1.9603
# Epoch : [175] ,  a_loss = 388.9199, d_loss: -0.1843 , db_loss: 1.0576
# Epoch : [176] ,  a_loss = 339.6712, d_loss: -0.1479 , db_loss: 1.1637
# Epoch : [177] ,  a_loss = 261.1292, d_loss: -0.2242 , db_loss: 2.6679
# Epoch : [178] ,  a_loss = 384.0300, d_loss: -0.1919 , db_loss: 0.8441
# Epoch : [179] ,  a_loss = 393.2258, d_loss: -0.1996 , db_loss: 0.8436
# Epoch : [180] ,  a_loss = 273.1559, d_loss: -0.1672 , db_loss: 2.2828
# Epoch : [181] ,  a_loss = 396.7535, d_loss: -0.2031 , db_loss: 0.9029
# Epoch : [182] ,  a_loss = 373.2238, d_loss: -0.2468 , db_loss: 0.7921
# Epoch : [183] ,  a_loss = 285.2740, d_loss: -0.1644 , db_loss: 1.5708
# Epoch : [184] ,  a_loss = 380.0682, d_loss: -0.2264 , db_loss: 1.0649
# Epoch : [185] ,  a_loss = 382.1322, d_loss: -0.1823 , db_loss: 1.1711
# Epoch : [186] ,  a_loss = 467.7594, d_loss: -0.2672 , db_loss: 0.3835
# Epoch : [187] ,  a_loss = 269.1375, d_loss: -0.2030 , db_loss: 2.3913
# Epoch : [188] ,  a_loss = 378.4434, d_loss: -0.2215 , db_loss: 0.7197
# Epoch : [189] ,  a_loss = 291.6639, d_loss: -0.1643 , db_loss: 1.8155
# Epoch : [190] ,  a_loss = 375.8228, d_loss: -0.1892 , db_loss: 0.9439
# Epoch : [191] ,  a_loss = 442.5364, d_loss: -0.2030 , db_loss: 0.3850
# Epoch : [192] ,  a_loss = 274.8667, d_loss: -0.1735 , db_loss: 2.1400
# Epoch : [193] ,  a_loss = 299.5797, d_loss: -0.2268 , db_loss: 2.0879
# Epoch : [194] ,  a_loss = 265.4538, d_loss: -0.2210 , db_loss: 2.4559
# Epoch : [195] ,  a_loss = 377.0367, d_loss: -0.2278 , db_loss: 0.7586
# Epoch : [196] ,  a_loss = 380.6068, d_loss: -0.2298 , db_loss: 0.8749
# Epoch : [197] ,  a_loss = 279.5191, d_loss: -0.1625 , db_loss: 2.1383
# Epoch : [198] ,  a_loss = 389.2986, d_loss: -0.2230 , db_loss: 0.9461
# Epoch : [199] ,  a_loss = 322.6904, d_loss: -0.2231 , db_loss: 2.2945
# Epoch : [200] ,  a_loss = 327.7863, d_loss: -0.1575 , db_loss: 1.2285
# latent_matrix shape (33506, 10)
# (33506,)
# None
# None
# Computing NMI ...
# Done !
# NMI = 0.8771330692896052
# Epoch : [201] ,  a_loss = 302.3722, d_loss: -0.1574 , db_loss: 2.0643
# Epoch : [202] ,  a_loss = 299.5139, d_loss: -0.1744 , db_loss: 1.7711
# Epoch : [203] ,  a_loss = 322.1250, d_loss: -0.1798 , db_loss: 2.1536
# Epoch : [204] ,  a_loss = 268.1934, d_loss: -0.1351 , db_loss: 2.5954
# Epoch : [205] ,  a_loss = 267.3608, d_loss: -0.2154 , db_loss: 2.4567
# Epoch : [206] ,  a_loss = 304.5970, d_loss: -0.1915 , db_loss: 2.0888
# Epoch : [207] ,  a_loss = 381.3888, d_loss: -0.1219 , db_loss: 0.8740
# Epoch : [208] ,  a_loss = 384.8964, d_loss: -0.2332 , db_loss: 0.9469
# Epoch : [209] ,  a_loss = 291.7393, d_loss: -0.2214 , db_loss: 2.9209
# Epoch : [210] ,  a_loss = 298.0457, d_loss: -0.2384 , db_loss: 2.3328
# Epoch : [211] ,  a_loss = 387.8704, d_loss: -0.2852 , db_loss: 0.7746
# Epoch : [212] ,  a_loss = 376.6151, d_loss: -0.1654 , db_loss: 0.9421
# Epoch : [213] ,  a_loss = 323.2803, d_loss: -0.1278 , db_loss: 1.9118
# Epoch : [214] ,  a_loss = 334.2125, d_loss: -0.1874 , db_loss: 1.4829
# Epoch : [215] ,  a_loss = 288.4675, d_loss: -0.2404 , db_loss: 2.1887
# Epoch : [216] ,  a_loss = 334.2560, d_loss: -0.1855 , db_loss: 1.3406
# Epoch : [217] ,  a_loss = 381.0231, d_loss: -0.1936 , db_loss: 1.0570
# Epoch : [218] ,  a_loss = 278.0517, d_loss: -0.3357 , db_loss: 2.0898
# Epoch : [219] ,  a_loss = 285.4502, d_loss: -0.2258 , db_loss: 2.7012
# Epoch : [220] ,  a_loss = 370.5327, d_loss: -0.2450 , db_loss: 0.8992
# Epoch : [221] ,  a_loss = 302.6736, d_loss: -0.2056 , db_loss: 2.3557
# Epoch : [222] ,  a_loss = 382.3795, d_loss: -0.2107 , db_loss: 0.9543
# Epoch : [223] ,  a_loss = 385.1306, d_loss: -0.2416 , db_loss: 0.7233
# Epoch : [224] ,  a_loss = 278.5300, d_loss: -0.2276 , db_loss: 2.1211
# Epoch : [225] ,  a_loss = 362.4462, d_loss: -0.2018 , db_loss: 0.8305
# Epoch : [226] ,  a_loss = 281.8862, d_loss: -0.1848 , db_loss: 2.0611
# Epoch : [227] ,  a_loss = 276.9371, d_loss: -0.2580 , db_loss: 1.9685
# Epoch : [228] ,  a_loss = 385.7049, d_loss: -0.1992 , db_loss: 0.9793
# Epoch : [229] ,  a_loss = 325.0031, d_loss: -0.3209 , db_loss: 1.9019
# Epoch : [230] ,  a_loss = 335.1506, d_loss: -0.2109 , db_loss: 1.2403
# Epoch : [231] ,  a_loss = 284.5300, d_loss: -0.1341 , db_loss: 2.1125
# Epoch : [232] ,  a_loss = 331.5790, d_loss: -0.2756 , db_loss: 1.1840
# Epoch : [233] ,  a_loss = 380.5602, d_loss: -0.2297 , db_loss: 0.8067
# Epoch : [234] ,  a_loss = 381.7685, d_loss: -0.2095 , db_loss: 1.0072
# Epoch : [235] ,  a_loss = 342.0672, d_loss: -0.2434 , db_loss: 1.4675
# Epoch : [236] ,  a_loss = 333.7912, d_loss: -0.5371 , db_loss: 1.1683
# Epoch : [237] ,  a_loss = 309.9197, d_loss: -0.3096 , db_loss: 2.0442
# Epoch : [238] ,  a_loss = 377.9784, d_loss: -0.2701 , db_loss: 1.1121
# Epoch : [239] ,  a_loss = 376.7576, d_loss: -0.2296 , db_loss: 1.0069
# Epoch : [240] ,  a_loss = 267.2268, d_loss: -0.4423 , db_loss: 2.1102
# Epoch : [241] ,  a_loss = 263.4686, d_loss: -0.3850 , db_loss: 2.5553
# Epoch : [242] ,  a_loss = 288.9376, d_loss: -0.5789 , db_loss: 1.8855
# Epoch : [243] ,  a_loss = 479.2920, d_loss: -0.2298 , db_loss: 0.7196
# Epoch : [244] ,  a_loss = 284.5305, d_loss: -0.4447 , db_loss: 2.8996
# Epoch : [245] ,  a_loss = 272.2884, d_loss: -0.6502 , db_loss: 1.9642
# Epoch : [246] ,  a_loss = 326.3977, d_loss: -0.3180 , db_loss: 1.5034
# Epoch : [247] ,  a_loss = 341.4913, d_loss: -0.3344 , db_loss: 0.7788
